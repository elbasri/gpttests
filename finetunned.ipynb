# %% [markdown]
# <a href="https://colab.research.google.com/github/elbasri/gpttests/blob/main/finetunned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# We just installed langchain library soo we can load our pdf or desired document then manipulate it as we want

# %%
from langchain.document_loaders import UnstructuredPDFLoader , OnlinePDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# we did import the tools to import our needed pdf then the tool to slice the pdf soo it will readable by chatgpt

# %%
# !pip install unstructured
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 21.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 39.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 80.9 MB/s eta 0:00:00
# ...

# %%
Pdfreader =  UnstructuredPDFLoader("data.pdf")

# %% [markdown]
# we just loaded our pdf in my case its the ompic law 17-97

# %%
# !pip install pdfminer.six

# %%
# !pip install pdf2image

# %% [markdown]
# just another library that will exract text from our pdf and we gonna use load function

# %%
lawdata = Pdfreader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-6dcd1fa2b0fe> in <cell line: 1>()
# ----> 1 lawdata = Pdfreader.load()
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/unstructured.py in load(self)
#      69     def load(self) -> List[Document]:
#      70         """Load file."""
# ---> 71         elements = self._get_elements()
#      72         if self.mode == "elements":
#      73             docs: List[Document] = list()
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/pdf.py in _get_elements(self)
#      35         from unstructured.partition.pdf import partition_pdf
#      36
# ---> 37         return partition_pdf(filename=self.file_path, **self.unstructured_kwargs)
#      38
#      39
#
# /usr/local/lib/python3.10/dist-packages/unstructured/documents/elements.py in wrapper(*args, **kwargs)
# ...

# %%
print(len(lawdata[0].page_content))
print("this the character count that we have in that pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c230f83a0ff3> in <cell line: 1>()
# ----> 1 print(len(lawdata[0].page_content))
#       2 print("this the character count that we have in that pdf")
#
# NameError: name 'lawdata' is not defined

# %%
doc_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=0)
Law_Slices =doc_splitter.split_documents(lawdata)

# %% [markdown]
# we just sliced our pdf

# %%
print(len(Law_Slices))
# Out:
# 126

# %%
# !pip install pinecone-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 12.2 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import Chroma,Pinecone
from langchain.embeddings.openai import OpenAIEmbeddings
import pinecone
# Out:
# /usr/local/lib/python3.10/dist-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.4 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.3 MB/s eta 0:00:00
# ...

# %%
api_key_gpt="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"
embeddings = OpenAIEmbeddings(openai_api_key=api_key_gpt)

# %%
pinecone.init(
	api_key='8a342b34-2c29-427c-9a3c-75e109661e72',
	environment='asia-southeast1-gcp'
)

index_name="tunnechat"

# %%
import pinecone

# %%
analysedocpdf =Pinecone.from_texts([lawpage.page_content for lawpage in Law_Slices],embeddings,index_name=index_name)

# %% [markdown]
# don't forget to set payement methode in api chatgpt

# %%
from langchain.chat_models import  ChatOpenAI
from langchain  import PromptTemplate , LLMChain
from langchain.prompts.chat import (
    ChatPromptTemplate ,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage,
)

# %%
llm = ChatOpenAI(model_name="gpt-4",temperature=0.25,openai_api_key=api_key_gpt,max_tokens=1000)

# %%
from backcall.backcall import sys
template ="You are a college student and im gonna ask you question and you should answer as best as you could and please answer in same language as the question was asked . {lawdocs}"
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
human_template="{question}"
human_messa_prompt = HumanMessagePromptTemplate.from_template(human_template)
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt,human_messa_prompt])
chain = LLMChain(llm=llm,prompt=chat_prompt)

# %%
quest="resume moi la parite de licencielement du contrat du travail"
docsprompt=analysedocpdf.similarity_search(quest)

# %%
chain.run(lawdocs=docsprompt, question=quest)
# Out:
# "Le licenciement du contrat de travail est un processus qui suit plusieurs étapes. D'abord, un procès-verbal est rédigé et doit être signé par les deux parties, puis remis au salarié. La décision de sanctions est également remise au salarié, soit en personne avec accusé de réception, soit par lettre recommandée, dans un délai de 48h à partir de la date de la prise de décision de sanction.\n\nL'inspecteur de travail peut intervenir si l'une des parties refuse d'accomplir ou de compléter les règles de procédure, ou pour recevoir la décision du licenciement ou de la démission. La décision du licenciement doit contenir les motifs qui ont justifié cette prise de décision, la date de l'audition et doit être assorti du procès-verbal en question.\n\nAprès la rupture du contrat, l'employeur est tenu de délivrer un certificat du travail au salarié contenant la date de son entrée et celle de sa sortie de l'emploi, ainsi que la qualification professionnelle de l'intéressé. L'employeur délivre ég
# ...

# %%
# !pip install openai

# %%
import os
import openai
openai.api_key = ''
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7f325d3ab860> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...
